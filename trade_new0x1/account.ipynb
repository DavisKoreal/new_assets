# %%
import ccxt
# importing datetime module for now()
import datetime
import asyncio
import json
import requests
import time
import sys


# KUCOINAPIKEY = sys.argv[1]
# KUCOINSECRET = sys.argv[2]  
# KUCOINPASSWORD = sys.argv[3]
KUCOINAPIKEY = "661bd98603e77600013bfd3d"
KUCOINSECRET = "7a0c92b9-69dc-40c0-8a01-30d73f660560"
#KUCOINPASSWORD = "47H6PJsb-5WRidM"
KUCOINPASSWORD = "*9Sd49G.!rt4RC$"
dollars_per_trade = 3
kucoin = ccxt.kucoin()


authentification = {
    "apiKey": f"{KUCOINAPIKEY}",
    "secret": f"{KUCOINSECRET}",
    "password": f"{KUCOINPASSWORD}",
}
kucoin = ccxt.kucoin(authentification)
print("This is done")
# Out:
# This is done

# %%
kucoin.fetch_balance()
# Out:
# {'info': {'code': '200000',
#   'data': [{'id': '65fdb6d2c76fbd00073b3ebb',
#     'currency': 'USDT',
#     'type': 'trade',
#     'balance': '8.89957276',
#     'available': '8.89957276',
#     'holds': '0'},
#    {'id': '663f2135e4e336000745cdb0',
#     'currency': 'HIBIRDS',
#     'type': 'trade',
#     'balance': '3.0305',
#     'available': '3.0305',
#     'holds': '0'},
#    {'id': '66375477b8a10400075d632a',
#     'currency': 'HIMAYC',
#     'type': 'trade',
#     'balance': '0.8021',
#     'available': '0.8021',
#     'holds': '0'},
#    {'id': '663f2121344d950007743795',
#     'currency': 'EGAME',
#     'type': 'trade',
#     'balance': '148.1587',
#     'available': '148.1587',
#     'holds': '0'},
#    {'id': '661be66fe7ceda0007990ff4',
#     'currency': 'HERO',
#     'type': 'trade',
#     'balance': '0.3819',
#     'available': '0.3819',
#     'holds': '0'},
#    {'id': '664785f4a8a674000742610a',
#     'currency': 'HIVALHALLA',
#     'type': 'trade',
#     'balance': '0.2923',
#     'available': '0.2923',
#     'holds': '0'},
#    {'id': '66478da814a521000796fe01',
#     'currency': 'PEPEUP',
#     'type': 'trade',
#     'balance': '0.000041',
#     'available': '0.000041',
#     'holds': '0'},
#    {'id': '66484f1bf3fb590007916117',
#     'currency': 'ALEX',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f22e4e33600077242ad',
#     'currency': 'ATEM',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f1f3c843f00076c775d',
#     'currency': 'AVA',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f2865264b0007818b84',
#     'currency': 'BICO',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '65fdb715b479b000078ca727',
#     'currency': 'BONDLY',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484ef2421bca000792b99e',
#     'currency': 'BOSON',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484bd43c843f00076a4224',
#     'currency': 'CCD',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f0b421bca000792cb32',
#     'currency': 'CGPT',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484eeece974f00075d41de',
#     'currency': 'CKB',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484eeace974f00075d3ec1',
#     'currency': 'CPOOL',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484ef814a52100072317a6',
#     'currency': 'CWAR',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484bd365264b00077f5127',
#     'currency': 'CWEB',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f28344d950007acc9ff',
#     'currency': 'DAO',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484efac4f81d0007a5311d',
#     'currency': 'DGB',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '661c0471963c210007faaa03',
#     'currency': 'DYDXUP',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f28421bca000792dcce',
#     'currency': 'ERG',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66478d618baefa00079fa40b',
#     'currency': 'FIRE',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484bd065264b00077f4f93',
#     'currency': 'FITFI',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f35ce974f00075d7119',
#     'currency': 'FTM3L',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484bcdaf0c5f0007a4decc',
#     'currency': 'GMEE',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66478da0f3fb590007052100',
#     'currency': 'HFT',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f22d7e7b300077e1320',
#     'currency': 'HIOD',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f1e3c843f00076c7678',
#     'currency': 'HMND',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f40ce974f00075d7819',
#     'currency': 'HON',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '664092a0b8f7090007b316ad',
#     'currency': 'KCS',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '663e4a07a8a6740007eb9aa0',
#     'currency': 'KICKS',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484efbb8f7090007d888d8',
#     'currency': 'LAYER',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f3365264b00078193d7',
#     'currency': 'LBP',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484efdc4f81d0007a53363',
#     'currency': 'LFT',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f36d7e7b300077e2103',
#     'currency': 'LYX',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '661bfe7ce7c3ed0007d39906',
#     'currency': 'MANA3L',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484bc2c0b38d000769b23b',
#     'currency': 'MAPO',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66478e25a8a67400074a3373',
#     'currency': 'MELOS',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '6647dfe68baefa0007de1672',
#     'currency': 'MONI',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f413c843f00076c8eb9',
#     'currency': 'MTV',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f01a8a6740007d6b39d',
#     'currency': 'MV',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '661c00b21e4f620007fa721b',
#     'currency': 'NEAR3L',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f1c8baefa00072d0d51',
#     'currency': 'NGL',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66478d5b8baefa00079f9c9a',
#     'currency': 'NHCT',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66478cabf3fb5900070429e1',
#     'currency': 'OLT',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '6655af249c567b000789ea9d',
#     'currency': 'OPEN',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '661bfe0f37c3a60007b86371',
#     'currency': 'ORDIUP',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '6647c577ce974f0007fc1c82',
#     'currency': 'PBX',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f06af0c5f0007a7053b',
#     'currency': 'POLS',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f27421bca000792dc41',
#     'currency': 'PRE',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66478db1e4e3360007e60c15',
#     'currency': 'PSTAKE',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f3765264b00078196b9',
#     'currency': 'REEF',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '661bffcffe5a1c0007c52ce9',
#     'currency': 'REVU',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '661bfe6c963c210007f37aef',
#     'currency': 'RNDRUP',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484f01421bca000792c3d9',
#     'currency': 'SILLY',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66478c76b8f70900074b4a50',
#     'currency': 'SLN',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484bdcc4f81d0007a31e27',
#     'currency': 'SQUAD',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484bdd421bca000790ab75',
#     'currency': 'STND',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '661c00c9e7ceda0007b7ce00',
#     'currency': 'SUI3S',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66484bcfaf0c5f0007a4dfa1',
#     'currency': 'TIDAL',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '661c04589f6cdd00072954ff',
#     'currency': 'TUNE',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '66478db9421bca000706ad9a',
#     'currency': 'UNI',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '6647dfe283b4d500076f33d3',
#     'currency': 'WOMBAT',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'},
#    {'id': '65fdb93d154bd30007505f50',
#     'currency': 'XCV',
#     'type': 'trade',
#     'balance': '0',
#     'available': '0',
#     'holds': '0'}]},
#  'timestamp': None,
#  'datetime': None,
#  'USDT': {'free': 8.89957276, 'used': 0.0, 'total': 8.89957276},
#  'HIBIRDS': {'free': 3.0305, 'used': 0.0, 'total': 3.0305},
#  'HIMAYC': {'free': 0.8021, 'used': 0.0, 'total': 0.8021},
#  'EGAME': {'free': 148.1587, 'used': 0.0, 'total': 148.1587},
#  'HERO': {'free': 0.3819, 'used': 0.0, 'total': 0.3819},
#  'HIVALHALLA': {'free': 0.2923, 'used': 0.0, 'total': 0.2923},
#  'PEPEUP': {'free': 4.1e-05, 'used': 0.0, 'total': 4.1e-05},
#  'ALEX': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'ATEM': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'AVA': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'BICO': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'BONDLY': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'BOSON': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'CCD': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'CGPT': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'CKB': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'CPOOL': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'CWAR': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'CWEB': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'DAO': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'DGB': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'DYDXUP': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'ERG': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'FIRE': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'FITFI': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'FTM3L': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'GMEE': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'HFT': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'HIOD': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'HMND': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'HON': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'KCS': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'KICKS': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'LAYER': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'LBP': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'LFT': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'LYX': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'MANA3L': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'MAPO': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'MELOS': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'MONI': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'MTV': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'MV': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'NEAR3L': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'NGL': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'NHCT': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'OLT': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'OPEN': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'ORDIUP': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'PBX': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'POLS': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'PRE': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'PSTAKE': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'REEF': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'REVU': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'RNDRUP': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'SILLY': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'SLN': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'SQUAD': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'STND': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'SUI3S': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'TIDAL': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'TUNE': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'UNI': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'WOMBAT': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'XCV': {'free': 0.0, 'used': 0.0, 'total': 0.0},
#  'free': {'USDT': 8.89957276,
#   'HIBIRDS': 3.0305,
#   'HIMAYC': 0.8021,
#   'EGAME': 148.1587,
#   'HERO': 0.3819,
#   'HIVALHALLA': 0.2923,
#   'PEPEUP': 4.1e-05,
#   'ALEX': 0.0,
#   'ATEM': 0.0,
#   'AVA': 0.0,
#   'BICO': 0.0,
#   'BONDLY': 0.0,
#   'BOSON': 0.0,
#   'CCD': 0.0,
#   'CGPT': 0.0,
#   'CKB': 0.0,
#   'CPOOL': 0.0,
#   'CWAR': 0.0,
#   'CWEB': 0.0,
#   'DAO': 0.0,
#   'DGB': 0.0,
#   'DYDXUP': 0.0,
#   'ERG': 0.0,
#   'FIRE': 0.0,
#   'FITFI': 0.0,
#   'FTM3L': 0.0,
#   'GMEE': 0.0,
#   'HFT': 0.0,
#   'HIOD': 0.0,
#   'HMND': 0.0,
#   'HON': 0.0,
#   'KCS': 0.0,
#   'KICKS': 0.0,
#   'LAYER': 0.0,
#   'LBP': 0.0,
#   'LFT': 0.0,
#   'LYX': 0.0,
#   'MANA3L': 0.0,
#   'MAPO': 0.0,
#   'MELOS': 0.0,
#   'MONI': 0.0,
#   'MTV': 0.0,
#   'MV': 0.0,
#   'NEAR3L': 0.0,
#   'NGL': 0.0,
#   'NHCT': 0.0,
#   'OLT': 0.0,
#   'OPEN': 0.0,
#   'ORDIUP': 0.0,
#   'PBX': 0.0,
#   'POLS': 0.0,
#   'PRE': 0.0,
#   'PSTAKE': 0.0,
#   'REEF': 0.0,
#   'REVU': 0.0,
#   'RNDRUP': 0.0,
#   'SILLY': 0.0,
#   'SLN': 0.0,
#   'SQUAD': 0.0,
#   'STND': 0.0,
#   'SUI3S': 0.0,
#   'TIDAL': 0.0,
#   'TUNE': 0.0,
#   'UNI': 0.0,
#   'WOMBAT': 0.0,
#   'XCV': 0.0},
#  'used': {'USDT': 0.0,
#   'HIBIRDS': 0.0,
#   'HIMAYC': 0.0,
#   'EGAME': 0.0,
#   'HERO': 0.0,
#   'HIVALHALLA': 0.0,
#   'PEPEUP': 0.0,
#   'ALEX': 0.0,
#   'ATEM': 0.0,
#   'AVA': 0.0,
#   'BICO': 0.0,
#   'BONDLY': 0.0,
#   'BOSON': 0.0,
#   'CCD': 0.0,
#   'CGPT': 0.0,
#   'CKB': 0.0,
#   'CPOOL': 0.0,
#   'CWAR': 0.0,
#   'CWEB': 0.0,
#   'DAO': 0.0,
#   'DGB': 0.0,
#   'DYDXUP': 0.0,
#   'ERG': 0.0,
#   'FIRE': 0.0,
#   'FITFI': 0.0,
#   'FTM3L': 0.0,
#   'GMEE': 0.0,
#   'HFT': 0.0,
#   'HIOD': 0.0,
#   'HMND': 0.0,
#   'HON': 0.0,
#   'KCS': 0.0,
#   'KICKS': 0.0,
#   'LAYER': 0.0,
#   'LBP': 0.0,
#   'LFT': 0.0,
#   'LYX': 0.0,
#   'MANA3L': 0.0,
#   'MAPO': 0.0,
#   'MELOS': 0.0,
#   'MONI': 0.0,
#   'MTV': 0.0,
#   'MV': 0.0,
#   'NEAR3L': 0.0,
#   'NGL': 0.0,
#   'NHCT': 0.0,
#   'OLT': 0.0,
#   'OPEN': 0.0,
#   'ORDIUP': 0.0,
#   'PBX': 0.0,
#   'POLS': 0.0,
#   'PRE': 0.0,
#   'PSTAKE': 0.0,
#   'REEF': 0.0,
#   'REVU': 0.0,
#   'RNDRUP': 0.0,
#   'SILLY': 0.0,
#   'SLN': 0.0,
#   'SQUAD': 0.0,
#   'STND': 0.0,
#   'SUI3S': 0.0,
#   'TIDAL': 0.0,
#   'TUNE': 0.0,
#   'UNI': 0.0,
#   'WOMBAT': 0.0,
#   'XCV': 0.0},
#  'total': {'USDT': 8.89957276,
#   'HIBIRDS': 3.0305,
#   'HIMAYC': 0.8021,
#   'EGAME': 148.1587,
#   'HERO': 0.3819,
#   'HIVALHALLA': 0.2923,
#   'PEPEUP': 4.1e-05,
#   'ALEX': 0.0,
#   'ATEM': 0.0,
#   'AVA': 0.0,
#   'BICO': 0.0,
#   'BONDLY': 0.0,
#   'BOSON': 0.0,
#   'CCD': 0.0,
#   'CGPT': 0.0,
#   'CKB': 0.0,
#   'CPOOL': 0.0,
#   'CWAR': 0.0,
#   'CWEB': 0.0,
#   'DAO': 0.0,
#   'DGB': 0.0,
#   'DYDXUP': 0.0,
#   'ERG': 0.0,
#   'FIRE': 0.0,
#   'FITFI': 0.0,
#   'FTM3L': 0.0,
#   'GMEE': 0.0,
#   'HFT': 0.0,
#   'HIOD': 0.0,
#   'HMND': 0.0,
#   'HON': 0.0,
#   'KCS': 0.0,
#   'KICKS': 0.0,
#   'LAYER': 0.0,
#   'LBP': 0.0,
#   'LFT': 0.0,
#   'LYX': 0.0,
#   'MANA3L': 0.0,
#   'MAPO': 0.0,
#   'MELOS': 0.0,
#   'MONI': 0.0,
#   'MTV': 0.0,
#   'MV': 0.0,
#   'NEAR3L': 0.0,
#   'NGL': 0.0,
#   'NHCT': 0.0,
#   'OLT': 0.0,
#   'OPEN': 0.0,
#   'ORDIUP': 0.0,
#   'PBX': 0.0,
#   'POLS': 0.0,
#   'PRE': 0.0,
#   'PSTAKE': 0.0,
#   'REEF': 0.0,
#   'REVU': 0.0,
#   'RNDRUP': 0.0,
#   'SILLY': 0.0,
#   'SLN': 0.0,
#   'SQUAD': 0.0,
#   'STND': 0.0,
#   'SUI3S': 0.0,
#   'TIDAL': 0.0,
#   'TUNE': 0.0,
#   'UNI': 0.0,
#   'WOMBAT': 0.0,
#   'XCV': 0.0}}

# %%
def get_token():
    url = "https://api.kucoin.com/api/v1/bullet-public"
    response = json.loads(requests.post(url).text)
    token = response['data']['token']
    #print(token)
    wsurl = response['data']['instanceServers']
    return token

get_token()
# Out:
# '2neAiuYvAU61ZDXANAGAsiL4-iAExhsBXZxftpOeh_55i3Ysy2q2LEsEWU64mdzUOPusi34M_wGoSf7iNyEWJ751xiGSPyebzyUy2oXl06UwcMPlW-6PiNiYB9J6i9GjsxUuhPw3BlrzazF6ghq4L93hHTSO1paWJCFQSppLjAw=.tfpBWYok2QDijX13JYQ7NQ=='

# %%
def sell(coin, number_of_coins_to_sell):
    order_type = 'market'
    side = 'sell'
    current_price = (kucoin.fetch_ticker(coin)['ask'] + kucoin.fetch_ticker(coin)['bid'] )/ 2
    value = current_price * float(number_of_coins_to_sell)
    profit = value - 1
    kucoin.create_order(coin, order_type, side, number_of_coins_to_sell)
    print(f"Sold {number_of_coins_to_sell} {coin} for {current_price} each")
    print("Made a profit of ", profit)


coin_to_be_sold = "EGAME-USDT"
nuumber_of_coins_to_sell = "148.1587"
sell(coin=coin_to_be_sold, number_of_coins_to_sell=nuumber_of_coins_to_sell)
# Out:
# ---------------------------------------------------------------------------
# InvalidOrder                              Traceback (most recent call last)
# Cell In[5], line 14
#      12 coin_to_be_sold = "EGAME-USDT"
#      13 nuumber_of_coins_to_sell = "148.1587"
# ---> 14 sell(coin=coin_to_be_sold, number_of_coins_to_sell=nuumber_of_coins_to_sell)
#
# Cell In[5], line 7, in sell(coin, number_of_coins_to_sell)
#       5 value = current_price * float(number_of_coins_to_sell)
#       6 profit = value - 1
# ----> 7 kucoin.create_order(coin, order_type, side, number_of_coins_to_sell)
#       8 print(f"Sold {number_of_coins_to_sell} {coin} for {current_price} each")
#       9 print("Made a profit of ", profit)
#
# File ~/.local/lib/python3.10/site-packages/ccxt/kucoin.py:1970, in kucoin.create_order(self, symbol, type, side, amount, price, params)
#    1968     response = self.privatePostMarginOrder(orderRequest)
#    1969 else:
# -> 1970     response = self.privatePostOrders(orderRequest)
#    1971 #
#    1972 #     {
#    1973 #         "code": "200000",
#    (...)
#    1977 #    }
#    1978 #
#    1979 data = self.safe_dict(response, 'data', {})
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/types.py:35, in Entry.__init__.<locals>.unbound_method(_self, params)
#      34 def unbound_method(_self, params={}):
# ---> 35     return _self.request(self.path, self.api, self.method, params, config=self.config)
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:3598, in Exchange.request(self, path, api, method, params, headers, body, config)
#    3597 def request(self, path, api: Any = 'public', method='GET', params={}, headers: Any = None, body: Any = None, config={}):
# -> 3598     return self.fetch2(path, api, method, params, headers, body, config)
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:3595, in Exchange.fetch2(self, path, api, method, params, headers, body, config)
#    3593 self.last_request_body = request['body']
#    3594 self.last_request_url = request['url']
# -> 3595 return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:672, in Exchange.fetch(self, url, method, headers, body)
#     669     else:
#     670         raise ExchangeError(details) from e
# --> 672 self.handle_errors(http_status_code, http_status_text, url, method, headers, http_response, json_response, request_headers, request_body)
#     673 if json_response is not None:
#     674     return json_response
#
# File ~/.local/lib/python3.10/site-packages/ccxt/kucoin.py:4432, in kucoin.handle_errors(self, code, reason, url, method, headers, body, response, requestHeaders, requestBody)
#    4430 feedback = self.id + ' ' + message
#    4431 self.throw_exactly_matched_exception(self.exceptions['exact'], message, feedback)
# -> 4432 self.throw_exactly_matched_exception(self.exceptions['exact'], errorCode, feedback)
#    4433 self.throw_broadly_matched_exception(self.exceptions['broad'], body, feedback)
#    4434 if errorCode != '200000' and errorCode != '200':
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:3965, in Exchange.throw_exactly_matched_exception(self, exact, string, message)
#    3963     return
#    3964 if string in exact:
# -> 3965     raise exact[string](message)
#
# InvalidOrder: kucoin The order amount must exceed 0.1 USDT.

# %%
coins = ["HERO-USDT","0.3819"]
for coin in coins:
    sell(coin=coin[0], number_of_coins_to_sell=coin[1])
# Out:
# Sold 8.2872 DYDXUP-USDT for 0.36995 each
# Made a profit of  2.06584964
# ---------------------------------------------------------------------------
# InvalidOrder                              Traceback (most recent call last)
# Cell In[6], line 3
#       1 coins = [['DYDXUP-USDT', "8.2872"], ['HIMAYC-USDT',"0.8021" ], ["HERO-USDT","0.3819"]]
#       2 for coin in coins:
# ----> 3     sell(coin=coin[0], number_of_coins_to_sell=coin[1])
#
# Cell In[5], line 7, in sell(coin, number_of_coins_to_sell)
#       5 value = current_price * float(number_of_coins_to_sell)
#       6 profit = value - 1
# ----> 7 kucoin.create_order(coin, order_type, side, number_of_coins_to_sell)
#       8 print(f"Sold {number_of_coins_to_sell} {coin} for {current_price} each")
#       9 print("Made a profit of ", profit)
#
# File ~/.local/lib/python3.10/site-packages/ccxt/kucoin.py:1970, in kucoin.create_order(self, symbol, type, side, amount, price, params)
#    1968     response = self.privatePostMarginOrder(orderRequest)
#    1969 else:
# -> 1970     response = self.privatePostOrders(orderRequest)
#    1971 #
#    1972 #     {
#    1973 #         "code": "200000",
#    (...)
#    1977 #    }
#    1978 #
#    1979 data = self.safe_dict(response, 'data', {})
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/types.py:35, in Entry.__init__.<locals>.unbound_method(_self, params)
#      34 def unbound_method(_self, params={}):
# ---> 35     return _self.request(self.path, self.api, self.method, params, config=self.config)
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:3598, in Exchange.request(self, path, api, method, params, headers, body, config)
#    3597 def request(self, path, api: Any = 'public', method='GET', params={}, headers: Any = None, body: Any = None, config={}):
# -> 3598     return self.fetch2(path, api, method, params, headers, body, config)
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:3595, in Exchange.fetch2(self, path, api, method, params, headers, body, config)
#    3593 self.last_request_body = request['body']
#    3594 self.last_request_url = request['url']
# -> 3595 return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:672, in Exchange.fetch(self, url, method, headers, body)
#     669     else:
#     670         raise ExchangeError(details) from e
# --> 672 self.handle_errors(http_status_code, http_status_text, url, method, headers, http_response, json_response, request_headers, request_body)
#     673 if json_response is not None:
#     674     return json_response
#
# File ~/.local/lib/python3.10/site-packages/ccxt/kucoin.py:4432, in kucoin.handle_errors(self, code, reason, url, method, headers, body, response, requestHeaders, requestBody)
#    4430 feedback = self.id + ' ' + message
#    4431 self.throw_exactly_matched_exception(self.exceptions['exact'], message, feedback)
# -> 4432 self.throw_exactly_matched_exception(self.exceptions['exact'], errorCode, feedback)
#    4433 self.throw_broadly_matched_exception(self.exceptions['broad'], body, feedback)
#    4434 if errorCode != '200000' and errorCode != '200':
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:3965, in Exchange.throw_exactly_matched_exception(self, exact, string, message)
#    3963     return
#    3964 if string in exact:
# -> 3965     raise exact[string](message)
#
# InvalidOrder: kucoin The order amount must exceed 0.1 USDT.

# %%
coins = ["HERO-USDT","0.3819"]
sell(coin=coins[0], number_of_coins_to_sell=coins[1])
# Out:
# ---------------------------------------------------------------------------
# InvalidOrder                              Traceback (most recent call last)
# Cell In[8], line 2
#       1 coins = ["HERO-USDT","0.3819"]
# ----> 2 sell(coin=coins[0], number_of_coins_to_sell=coins[1])
#
# Cell In[5], line 7, in sell(coin, number_of_coins_to_sell)
#       5 value = current_price * float(number_of_coins_to_sell)
#       6 profit = value - 1
# ----> 7 kucoin.create_order(coin, order_type, side, number_of_coins_to_sell)
#       8 print(f"Sold {number_of_coins_to_sell} {coin} for {current_price} each")
#       9 print("Made a profit of ", profit)
#
# File ~/.local/lib/python3.10/site-packages/ccxt/kucoin.py:1970, in kucoin.create_order(self, symbol, type, side, amount, price, params)
#    1968     response = self.privatePostMarginOrder(orderRequest)
#    1969 else:
# -> 1970     response = self.privatePostOrders(orderRequest)
#    1971 #
#    1972 #     {
#    1973 #         "code": "200000",
#    (...)
#    1977 #    }
#    1978 #
#    1979 data = self.safe_dict(response, 'data', {})
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/types.py:35, in Entry.__init__.<locals>.unbound_method(_self, params)
#      34 def unbound_method(_self, params={}):
# ---> 35     return _self.request(self.path, self.api, self.method, params, config=self.config)
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:3598, in Exchange.request(self, path, api, method, params, headers, body, config)
#    3597 def request(self, path, api: Any = 'public', method='GET', params={}, headers: Any = None, body: Any = None, config={}):
# -> 3598     return self.fetch2(path, api, method, params, headers, body, config)
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:3595, in Exchange.fetch2(self, path, api, method, params, headers, body, config)
#    3593 self.last_request_body = request['body']
#    3594 self.last_request_url = request['url']
# -> 3595 return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:672, in Exchange.fetch(self, url, method, headers, body)
#     669     else:
#     670         raise ExchangeError(details) from e
# --> 672 self.handle_errors(http_status_code, http_status_text, url, method, headers, http_response, json_response, request_headers, request_body)
#     673 if json_response is not None:
#     674     return json_response
#
# File ~/.local/lib/python3.10/site-packages/ccxt/kucoin.py:4432, in kucoin.handle_errors(self, code, reason, url, method, headers, body, response, requestHeaders, requestBody)
#    4430 feedback = self.id + ' ' + message
#    4431 self.throw_exactly_matched_exception(self.exceptions['exact'], message, feedback)
# -> 4432 self.throw_exactly_matched_exception(self.exceptions['exact'], errorCode, feedback)
#    4433 self.throw_broadly_matched_exception(self.exceptions['broad'], body, feedback)
#    4434 if errorCode != '200000' and errorCode != '200':
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:3965, in Exchange.throw_exactly_matched_exception(self, exact, string, message)
#    3963     return
#    3964 if string in exact:
# -> 3965     raise exact[string](message)
#
# InvalidOrder: kucoin The order amount must exceed 0.1 USDT.

# %%
kucoin.fetch_balance()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:628, in Exchange.fetch(self, url, method, headers, body)
#     627     self.logger.debug("%s %s, Response: %s %s %s", method, url, http_status_code, headers, http_response)
# --> 628     response.raise_for_status()
#     630 except Timeout as e:
#
# File ~/.local/lib/python3.10/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.kucoin.com/api/v1/accounts?type=trade
#
# During handling of the above exception, another exception occurred:
#
# InvalidNonce                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 kucoin.fetch_balance()
#
# File ~/.local/lib/python3.10/site-packages/ccxt/kucoin.py:3366, in kucoin.fetch_balance(self, params)
#    3364         request['currency'] = currency['id']
#    3365     request['type'] = type
# -> 3366     response = self.privateGetAccounts(self.extend(request, query))
#    3367 #
#    3368 # Spot and Cross
#    3369 #
#    (...)
#    3418 #    }
#    3419 #
#    3420 data = self.safe_list(response, 'data', [])
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/types.py:35, in Entry.__init__.<locals>.unbound_method(_self, params)
#      34 def unbound_method(_self, params={}):
# ---> 35     return _self.request(self.path, self.api, self.method, params, config=self.config)
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:3598, in Exchange.request(self, path, api, method, params, headers, body, config)
#    3597 def request(self, path, api: Any = 'public', method='GET', params={}, headers: Any = None, body: Any = None, config={}):
# -> 3598     return self.fetch2(path, api, method, params, headers, body, config)
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:3595, in Exchange.fetch2(self, path, api, method, params, headers, body, config)
#    3593 self.last_request_body = request['body']
#    3594 self.last_request_url = request['url']
# -> 3595 return self.fetch(request['url'], request['method'], request['headers'], request['body'])
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:644, in Exchange.fetch(self, url, method, headers, body)
#     642 except HTTPError as e:
#     643     details = ' '.join([self.id, method, url])
# --> 644     skip_further_error_handling = self.handle_errors(http_status_code, http_status_text, url, method, headers, http_response, json_response, request_headers, request_body)
#     645     if not skip_further_error_handling:
#     646         self.handle_http_status_code(http_status_code, http_status_text, url, method, http_response)
#
# File ~/.local/lib/python3.10/site-packages/ccxt/kucoin.py:4432, in kucoin.handle_errors(self, code, reason, url, method, headers, body, response, requestHeaders, requestBody)
#    4430 feedback = self.id + ' ' + message
#    4431 self.throw_exactly_matched_exception(self.exceptions['exact'], message, feedback)
# -> 4432 self.throw_exactly_matched_exception(self.exceptions['exact'], errorCode, feedback)
#    4433 self.throw_broadly_matched_exception(self.exceptions['broad'], body, feedback)
#    4434 if errorCode != '200000' and errorCode != '200':
#
# File ~/.local/lib/python3.10/site-packages/ccxt/base/exchange.py:3965, in Exchange.throw_exactly_matched_exception(self, exact, string, message)
#    3963     return
#    3964 if string in exact:
# -> 3965     raise exact[string](message)
#
# InvalidNonce: kucoin Invalid KC-API-TIMESTAMP
